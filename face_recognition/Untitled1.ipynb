# %%
import numpy as np
import cv2
import face_recognition
import matplotlib.pyplot as plt
# %matplotlib inline

# Load an color image in grayscale
img = cv2.imread('image_data/test2.jpg')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
face_locations = face_recognition.face_locations(img_rgb)
for face in face_locations:
    print("face: ",face)
    top, right, bottom, left = face
    color = (255, 255, 0) 
    # Line thickness of 2 px 
    thickness = 5
    cv2.rectangle(img_rgb,(left,top),(right,bottom),color,thickness)
plt.imshow(img_rgb)
# Out:
# face:  (229, 469, 304, 395)
# face:  (546, 892, 653, 784)
# face:  (514, 583, 604, 494)
# face:  (255, 603, 345, 514)
# face:  (104, 199, 211, 91)

# %%
import numpy as np
import cv2
import face_recognition
import matplotlib.pyplot as plt
# %matplotlib inline

cap = cv2.VideoCapture(0)
cap.set(3, 640)  # set Width
cap.set(4, 480)  # set Height
while (True):
    ret, frame = cap.read()
    # frame = cv2.flip(frame, -1) #Flip camera vertically
    if ret:
        face_locations = face_recognition.face_locations(frame)
        for face in face_locations:
            print("face: ",face)
            top, right, bottom, left = face
            color = (0, 0, 0) 
            # Line thickness of 2 px 
            thickness = 5
            cv2.rectangle(frame,(left,top),(right,bottom),color,thickness)
            
        cv2.imshow('Class1', frame)


        k = cv2.waitKey(30) & 0xff
    if k == 27:  # press 'ESC' to quit
        print("Call ESC")
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# face:  (236, 425, 391, 270)
# face:  (236, 408, 391, 253)
# face:  (236, 408, 391, 253)
# face:  (236, 408, 391, 253)
# face:  (222, 428, 407, 242)
# face:  (236, 408, 391, 253)
# face:  (236, 425, 391, 270)
# face:  (236, 425, 391, 270)
# face:  (236, 425, 391, 270)
# face:  (201, 469, 387, 283)
# face:  (201, 489, 387, 304)
# face:  (201, 469, 387, 283)
# face:  (219, 425, 374, 270)
# face:  (219, 425, 374, 270)
# face:  (219, 425, 374, 270)
# face:  (219, 425, 374, 270)
# face:  (219, 425, 374, 270)
# face:  (219, 425, 374, 270)
# face:  (219, 425, 374, 270)
# face:  (219, 425, 374, 270)
# face:  (219, 425, 374, 270)
# face:  (219, 425, 374, 270)
# face:  (219, 408, 374, 253)
# face:  (219, 425, 374, 270)
# face:  (219, 425, 374, 270)
# face:  (201, 448, 387, 262)
# face:  (201, 448, 387, 262)
# face:  (219, 442, 374, 287)
# face:  (219, 442, 374, 287)
# face:  (219, 442, 374, 287)
# face:  (219, 442, 374, 287)
# face:  (219, 425, 374, 270)
# face:  (219, 442, 374, 287)
# face:  (219, 442, 374, 287)
# face:  (201, 448, 387, 262)
# face:  (219, 425, 374, 270)
# face:  (219, 425, 374, 270)
# face:  (219, 442, 374, 287)
# face:  (201, 448, 387, 262)
# face:  (201, 448, 387, 262)
# face:  (219, 442, 374, 287)
# face:  (201, 448, 387, 262)
# face:  (201, 448, 387, 262)
# face:  (219, 425, 374, 270)
# face:  (201, 448, 387, 262)
# face:  (201, 448, 387, 262)
# face:  (201, 448, 387, 262)
# face:  (201, 448, 387, 262)
# face:  (219, 425, 374, 270)
# face:  (219, 425, 374, 270)
# face:  (219, 425, 374, 270)
# face:  (219, 425, 374, 270)
# face:  (262, 225, 298, 189)
# face:  (219, 425, 374, 270)
# face:  (262, 229, 298, 193)
# face:  (219, 425, 374, 270)
# face:  (147, 262, 199, 210)
# face:  (136, 227, 188, 175)
# face:  (222, 448, 407, 262)
# face:  (222, 448, 407, 262)
# face:  (122, 225, 184, 163)
# face:  (219, 442, 374, 287)
# face:  (105, 229, 179, 154)
# face:  (219, 442, 374, 287)
# face:  (101, 204, 163, 142)
# face:  (236, 442, 391, 287)
# face:  (88, 187, 163, 113)
# face:  (236, 442, 391, 287)
# face:  (101, 176, 163, 114)
# face:  (222, 448, 407, 262)
# face:  (236, 425, 391, 270)
# face:  (236, 425, 391, 270)
# face:  (236, 425, 391, 270)
# face:  (258, 245, 294, 209)
# face:  (236, 425, 391, 270)
# face:  (270, 237, 306, 201)
# face:  (236, 425, 391, 270)
# face:  (222, 448, 407, 262)
# face:  (236, 442, 391, 287)
# face:  (219, 442, 374, 287)
# face:  (219, 442, 374, 287)
# face:  (201, 469, 387, 283)
# face:  (201, 469, 387, 283)
# face:  (219, 442, 374, 287)
# face:  (219, 408, 374, 253)
# face:  (98, 634, 284, 448)
# face:  (219, 390, 374, 236)
# face:  (219, 408, 374, 253)
# face:  (219, 425, 374, 270)
# face:  (219, 425, 374, 270)
# face:  (219, 425, 374, 270)
# face:  (219, 425, 374, 270)
# face:  (219, 408, 374, 253)
# face:  (219, 408, 374, 253)
# face:  (219, 425, 374, 270)
# face:  (219, 425, 374, 270)
# face:  (219, 425, 374, 270)
# face:  (274, 209, 310, 173)
# face:  (219, 425, 374, 270)
# face:  (219, 425, 374, 270)
# face:  (219, 425, 374, 270)
# face:  (219, 425, 374, 270)
# face:  (219, 425, 374, 270)
# face:  (219, 425, 374, 270)
# face:  (219, 425, 374, 270)
# face:  (201, 448, 387, 262)
# face:  (219, 442, 374, 287)
# face:  (201, 448, 387, 262)
# face:  (219, 425, 374, 270)
# face:  (219, 425, 374, 270)
# face:  (219, 425, 374, 270)
# face:  (219, 425, 374, 270)
# face:  (219, 425, 374, 270)
# face:  (219, 425, 374, 270)
# face:  (219, 425, 374, 270)
# face:  (219, 425, 374, 270)
# face:  (219, 425, 374, 270)
# face:  (236, 425, 391, 270)
# face:  (236, 425, 391, 270)
# face:  (236, 425, 391, 270)
# face:  (236, 425, 391, 270)
# face:  (236, 425, 391, 270)
# face:  (236, 425, 391, 270)
# face:  (253, 425, 408, 270)
# face:  (253, 408, 408, 253)
# face:  (242, 407, 428, 221)
# face:  (263, 428, 449, 242)
# face:  (263, 469, 449, 283)
# face:  (242, 469, 428, 283)
# face:  (242, 489, 428, 304)
# face:  (222, 489, 407, 304)
# face:  (201, 489, 387, 304)
# face:  (201, 510, 387, 324)
# face:  (201, 489, 387, 304)
# face:  (201, 489, 387, 304)
# face:  (201, 469, 387, 283)
# face:  (201, 448, 387, 262)
# face:  (219, 408, 374, 253)
# face:  (219, 390, 374, 236)
# Call ESC
