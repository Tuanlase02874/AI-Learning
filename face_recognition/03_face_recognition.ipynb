# %%
import numpy as np
import cv2
import numpy as np
import matplotlib.pyplot as plt
import face_recognition
# %matplotlib inline


# Load an color image in grayscale
img = cv2.imread('image_data/user_name.jpg')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
print("Image Shape:", img.shape)
# Out:
# Image Shape: (912, 668, 3)

# %%
# Load an color image in grayscale
img2 = cv2.imread('image_data/test2.jpg')
img_rgb2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb2)
print("Image Shape:", img2.shape)
# Out:
# Image Shape: (1080, 1080, 3)

# %%
face_locations = face_recognition.face_locations(img_rgb)
print("face_locations :", face_locations)
face_encodings = face_recognition.face_encodings(img_rgb, face_locations)
print("face_encodings :", face_encodings)
# Out:
# face_locations : [(241, 491, 562, 170)]
# face_encodings : [array([-0.09622915,  0.0882685 ,  0.0614684 , -0.15548691, -0.15500246,
#        -0.02091342, -0.12804992, -0.04878959,  0.14991891, -0.15288325,
#         0.19335748, -0.07627144, -0.27342081, -0.0462162 , -0.04045966,
#         0.2746073 , -0.16637832, -0.14272584, -0.01909922,  0.03120725,
#         0.09116289,  0.05130622,  0.03234734,  0.0976951 , -0.15825355,
#        -0.37925765, -0.08408883,  0.02963443, -0.12161598, -0.09870566,
#        -0.08723915,  0.08652246, -0.21087471, -0.01605596,  0.02255088,
#         0.16609445,  0.00994209, -0.13846529,  0.12760437,  0.09293052,
#        -0.32945865,  0.02146799,  0.09669018,  0.24956226,  0.14545795,
#        -0.00168495,  0.02961629, -0.08978745,  0.11706293, -0.24686345,
#         0.02167234,  0.13161908,  0.04577392, -0.00966882,  0.00449888,
#        -0.09157132,  0.05475177,  0.15997514, -0.15501541, -0.0748857 ,
# ...

# %%
face_locations2 = face_recognition.face_locations(img_rgb2)
print("face_locations :", face_locations2)
face_encodings2 = face_recognition.face_encodings(img_rgb2, face_locations2)
#print("face_encodings :", face_encodings2)
for face_encode in face_encodings2:
    print("print face encode shape:",face_encode.shape )
# Out:
# face_locations : [(229, 469, 304, 395), (546, 892, 653, 784), (514, 583, 604, 494), (255, 603, 345, 514), (104, 199, 211, 91)]
# print face encode shape: (128,)
# print face encode shape: (128,)
# print face encode shape: (128,)
# print face encode shape: (128,)
# print face encode shape: (128,)
