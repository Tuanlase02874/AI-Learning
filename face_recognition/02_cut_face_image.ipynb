# %%
import numpy as np
import cv2
import numpy as np
import matplotlib.pyplot as plt
import face_recognition
# %matplotlib inline


# Load an color image in grayscale
img = cv2.imread('image_data/user_name.jpg')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
print("Image Shape:", img.shape)
# Out:
# Image Shape: (912, 668, 3)

# %%
face_locations = face_recognition.face_locations(img_rgb)
if len(face_locations) == 1:
    top, right, bottom, left = face_locations[0]
    face_img = img[top:bottom,left:right,:]
    cv2.imwrite("class_image/user_test.jpg", face_img) 
    print("Save face image in class_image/user_test.jpg")
# Out:
# Save face image in class_image/user_test.jpg
